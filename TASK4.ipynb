# %% [markdown]
# <a href="https://colab.research.google.com/github/sensiboi/TECHNOHACKS-EDUTECH-TASK/blob/main/TASK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK4 Pivot Table**

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.pivot_table(index='Age',columns='Sex',values='Survived').dropna(thresh=1)
# Out:
# Sex    female  male
# Age
# 0.42      NaN   1.0
# 0.67      NaN   1.0
# 0.75      1.0   NaN
# 0.83      NaN   1.0
# 0.92      NaN   1.0
# ...       ...   ...
# 70.00     NaN   0.0
# 70.50     NaN   0.0
# 71.00     NaN   0.0
# 74.00     NaN   0.0
# 80.00     NaN   1.0
#
# [88 rows x 2 columns]
